# %%
# %matplotlib inline
import numpy as np
from scipy import fftpack
from matplotlib import pyplot as plt

# %%
def ConvertToHex(value,bitwidth):
    """
    Converts the value field to 2's compliment hex format
    :param value:  value to convert
    :param bitwidth:   bitwidth of number
    :return:  converted value
    """
    value = int(value)
    if (value > (2**(bitwidth-1) - 1)):
        print('bit conversion failed, too positive')
        return "NULL"
    if (value < -(2**(bitwidth))):
        print('bit conversiion failed, too negative')
        return "NULL"
    # handle negative calculation
    if (value < 0):
        # wrap around to larger positive value, since
        # hex(-100) = -0x64, a not useful response
        value = value + 2**bitwidth;
    value_string = hex(value)
    # now if the value was positive, we want it
    # to take up the correct number of bits
    # chop of the 0x portion
    value_string = value_string[2: ]
    zeros_to_pad = bitwidth // 4 - len(value_string)
    string_out = zeros_to_pad*'0' + value_string
    return string_out

# %%
# First create the sinewave at 640Msps that we interpolate to 640.625Msps
t = np.arange(65536)
Fs = 640
F = 300
sig_in = (2**10)*(np.cos(2*np.pi*F/Fs*t) + 1j*np.sin(2*np.pi*F/Fs*t))
sig_round = np.round(sig_in)

# %%
wave_640_hex_real = []
wave_640_hex_imag = []

for x, item in enumerate(sig_round):
    wave_640_hex_real.append(ConvertToHex(item.real, 12))
    wave_640_hex_imag.append(ConvertToHex(item.imag, 12))

# %%
f1 = open('waveform_tone_640_real.dat', 'w')
f2 = open('waveform_tone_640_imag.dat', 'w')

for item in wave_640_hex_real:
    f1.write(f'{item}\n')

for item in wave_640_hex_imag:
    f2.write(f'{item}\n')

    
f1.close()
f2.close()

# %%
# create the sinewave at 530Msps that we interpolate to 640.625Msps
t = np.arange(65536)
Fs = 530
F = 200
sig_in = (2**10)*(np.cos(2*np.pi*F/Fs*t) + 1j*np.sin(2*np.pi*F/Fs*t))
sig_round = np.round(sig_in)
wave_530_hex_real = []
wave_530_hex_imag = []

for x, item in enumerate(sig_round):
    wave_530_hex_real.append(ConvertToHex(item.real, 12))
    wave_530_hex_imag.append(ConvertToHex(item.imag, 12))

f1 = open('waveform_tone_530_real.dat', 'w')
f2 = open('waveform_tone_530_imag.dat', 'w')

for item in wave_530_hex_real:
    f1.write(f'{item}\n')

for item in wave_530_hex_imag:
    f2.write(f'{item}\n')

    
f1.close()
f2.close()

# %%
sig_round[2]
# Out:
# (30-1024j)

# %%
# create the sinewave at 530Msps that we interpolate to 640.625Msps
t = np.arange(65536)
Fs = 430
F = 100
sig_in = (2**10)*(np.cos(2*np.pi*F/Fs*t) + 1j*np.sin(2*np.pi*F/Fs*t))
sig_round = np.round(sig_in)
wave_430_hex_real = []
wave_430_hex_imag = []

for x, item in enumerate(sig_round):
    wave_430_hex_real.append(ConvertToHex(item.real, 12))
    wave_430_hex_imag.append(ConvertToHex(item.imag, 12))

f1 = open('waveform_tone_430_real.dat', 'w')
f2 = open('waveform_tone_430_imag.dat', 'w')

for item in wave_430_hex_real:
    f1.write(f'{item}\n')

for item in wave_430_hex_imag:
    f2.write(f'{item}\n')

    
f1.close()
f2.close()

# %%
plt.plot(sig_round.real[0:100])

# %%
# now make a very slow tone to eyeball errors
# create the sinewave at 640Msps that we interpolate to 640.625Msps
t = np.arange(65536)
Fs = 640
F = 1
sig_in = (2**10)*(np.cos(2*np.pi*F/Fs*t) + 1j*np.sin(2*np.pi*F/Fs*t))
sig_round = np.round(sig_in)
wave_640_hex_real = []
wave_640_hex_imag = []

for x, item in enumerate(sig_round):
    wave_640_hex_real.append(ConvertToHex(item.real, 12))
    wave_640_hex_imag.append(ConvertToHex(item.imag, 12))

f1 = open('waveform_tone_640_1_real.dat', 'w')
f2 = open('waveform_tone_640_1_imag.dat', 'w')

for item in wave_640_hex_real:
    f1.write(f'{item}\n')

for item in wave_640_hex_imag:
    f2.write(f'{item}\n')

    
f1.close()
f2.close()

# %%
# now make a very slow tone to eyeball errors
# create the sinewave at 530Msps that we interpolate to 640.625Msps
t = np.arange(65536)
Fs = 530
F = 1
sig_in = (2**10)*(np.cos(2*np.pi*F/Fs*t) + 1j*np.sin(2*np.pi*F/Fs*t))
sig_round = np.round(sig_in)
wave_640_hex_real = []
wave_640_hex_imag = []

for x, item in enumerate(sig_round):
    wave_640_hex_real.append(ConvertToHex(item.real, 12))
    wave_640_hex_imag.append(ConvertToHex(item.imag, 12))

f1 = open('waveform_tone_530_1_real.dat', 'w')
f2 = open('waveform_tone_530_1_imag.dat', 'w')

for item in wave_640_hex_real:
    f1.write(f'{item}\n')

for item in wave_640_hex_imag:
    f2.write(f'{item}\n')

    
f1.close()
f2.close()
